# %%
import missingno as msno
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(np.random.randn(10000,100))
for i in range(100):
    df[i][df[i]<0] = None

# %%
msno.matrix(df)

# %%
plt.show()
